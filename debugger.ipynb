# %%
price = 200
tax = 20
discount = 10
taxed_price = price + (price * tax/100)
discounted_price = taxed_price - (taxed_price * discount/100)
print(discounted_price)

# %%
price = 200
tax = 20
discount = 10
taxed_price = price + (price * tax/100)
discounted_price = taxed_price - (taxed_price * discount/100)
print(discounted_price)
