# %%
# %sql
select 1;

# %% [markdown]
# Using spark.sql

# %%
df = spark.sql('select * from json.`/Volumes/gizmobox/landing/operational_data/customers`')
display(df)

# %%
df = spark.sql(''' create temporary view temporary_v_customers
               as
               select * from 
               json.`/Volumes/gizmobox/landing/operational_data/customers`''')

# %%
# %sql
select * from temporary_v_customers;
-- switching approach to SQL - it works :)

# %% [markdown]
# Using spark dataframe reader API

# %%
df = spark.read.format('json').load('/Volumes/gizmobox/landing/operational_data/customers')
display(df)

# %% [markdown]
# Using spark.table function

# %%
df = spark.table('gizmobox.bronze.v_customers')
display(df)
