# %% [markdown]
# **External Tables**

# %% [markdown]
# List Files from Payments Folder

# %%
# %fs ls 'abfss://gizmobox@salarcourseextdl.dfs.core.windows.net/landing/external_data/payments/'

# %% [markdown]
# Create External Table

# %%
# %sql
create table if not exists gizmobox.bronze.payments
(
  payment_id integer,
  order_id integer,
  payment_timestamp timestamp,
  payment_status integer,
  payment_method string
) using csv
options (
  header='true',
  delimiter=','
)
location'abfss://gizmobox@salarcourseextdl.dfs.core.windows.net/landing/external_data/payments/'

# %%
# %sql
select * from gizmobox.bronze.payments;

# %%
# %sql
describe extended gizmobox.bronze.payments;

# %% [markdown]
# Demonstrate if file is deleted

# %%
# %sql
select * from gizmobox.bronze.payments;
--query run post-delete single file

# %%
# %sql
refresh table gizmobox.bronze.payments;
-- soltion. as it updates the metadata

# %%
# %sql
select * from gizmobox.bronze.payments;
--tried again. Worked !

# %% [markdown]
# Demonstrate if table is dropped

# %%
# %sql
drop table if exists gizmobox.bronze.payments;
-- table drops but metadata stays. not the same in managed tables.
