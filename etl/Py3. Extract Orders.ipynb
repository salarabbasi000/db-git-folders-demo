# %% [markdown]
# **Extract data from Orders Files (JSON)**

# %%
# %sql
SELECT * FROM text.`dbfs:/Volumes/gizmobox/landing/operational_data/orders/`
-- because json format cannot hold it (data quality issues). Column: corrupt_record

# %%
df = spark.read.json('dbfs:/Volumes/gizmobox/landing/operational_data/orders/')
display(df)

# %%
df = spark.read.text('dbfs:/Volumes/gizmobox/landing/operational_data/orders/')
display(df)

# %%
df.writeTo('gizmobox.bronze.py_orders').createOrReplace()

# %%
# %sql
select * from gizmobox.bronze.py_orders;
