# %%
# %sql
create table if not exists hive_metastore.bronze.refunds
using jdbc
options (
url 'jdbc:sqlserver://gizmobox-srv-exam.database.windows.net:1433;database=gizmobox-db',
dbtable '<>',
user '<>',
password '<>'
)

# %%
df = (spark.read
      .format("jdbc")
      .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver")
      .option("url", "jdbc:sqlserver://gizmobox-srv-exam.database.windows.net:1433;database=gizmobox-db")
      .option("dbtable", "<>")
      .option("user", "<>")
      .option("password", "<>")
      .load()
      )

display(df)

# %%
df.writeTo('gizmobox.bronze.py_refunds').createOrReplace()

# %%
# %sql
select * from gizmobox.bronze.py_refunds;
