# %% [markdown]
# profiling are checks before proceeding with transformation

# %% [markdown]
# 3 approaches:
# 1) Databricks UI
# 2) Via Dbutils - dbutils.data.summarize(df)
# 3) Manual Checks: count(), countIf(), sum(), count(distinct colName), etc...

# %%
# %sql
select * from gizmobox.bronze.v_customers
# Out:
# Databricks data profile. Run in Databricks to view.

# %%
df = spark.table('gizmobox.bronze.v_customers')
dbutils.data.summarize(df)
