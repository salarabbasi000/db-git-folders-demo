# %% [markdown]
# **Extract data from Orders Files (JSON)**

# %%
print('hi')

# %%
# %sql
SELECT * FROM text.`dbfs:/Volumes/gizmobox/landing/operational_data/orders/`
-- because json format cannot hold it (data quality issues). Column: corrupt_record

# %% [markdown]
# Create View

# %%
# %sql
create or replace view gizmobox.bronze.v_orders
as
select
*, _metadata.file_path as file_path
FROM text.`dbfs:/Volumes/gizmobox/landing/operational_data/orders/`

# %%
# %sql
select * from gizmobox.bronze.v_orders;

# %% [markdown]
# Create Temporary View

# %%
# %sql
create or replace temporary view v_orders
as
select
*, _metadata.file_path as file_path
FROM json.`dbfs:/Volumes/gizmobox/landing/operational_data/orders/`

# %%
# %sql
select * from v_orders;

# %% [markdown]
# Create Global Temporary View

# %%
# %sql
create or replace global temporary view v_orders
as
select
*, _metadata.file_path as file_path
FROM json.`dbfs:/Volumes/gizmobox/landing/operational_data/orders/`

# %%
# %sql
select * from global_temp.v_orders;
