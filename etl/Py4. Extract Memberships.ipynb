# %% [markdown]
# **Extract data from Memberships Files (Png)**

# %%
# %fs ls 'dbfs:/Volumes/gizmobox/landing/operational_data/memberships/'
-- because there are multiple folders inside memberships folder

# %%
# %sql
select * from binaryFile.`dbfs:/Volumes/gizmobox/landing/operational_data/memberships/*/*.png`
-- because there are multiple folders inside memberships folder as can be seen in above cell
-- metadata here by default

# %%
# need to use format() method, as binaryFile() doesn't exist.
df = spark.read.format("binaryFile").load("dbfs:/Volumes/gizmobox/landing/operational_data/memberships/*/*.png")
display(df)

# %%
df.writeTo("gizmobox.bronze.py_memberships").createOrReplace()

# %%
# %sql
select * from gizmobox.bronze.py_memberships;
